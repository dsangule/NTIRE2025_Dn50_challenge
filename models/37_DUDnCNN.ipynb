# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
import os
import numpy as np
from PIL import Image
import time
import cv2

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Test Dataset
class TestDenoisingDataset(Dataset):
    def __init__(self, test_dir, transform=None):
        self.test_dir = test_dir
        self.transform = transform
        self.image_files = [f for f in os.listdir(test_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]
        self.resize_transform = transforms.Resize((256, 256), antialias=True)

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_path = os.path.join(self.test_dir, self.image_files[idx])
        image = Image.open(image_path).convert("RGB")
        image = self.resize_transform(image)
        if self.transform:
            image = self.transform(image)
        return image, self.image_files[idx]

# Neural Network Base Class
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()

    @property
    def device(self):
        return next(self.parameters()).device

    def forward(self, x):
        raise NotImplementedError

# NN Regressor Base Class
class NNRegressor(NeuralNetwork):
    def __init__(self):
        super(NNRegressor, self).__init__()
        self.mse = nn.MSELoss()

    def criterion(self, y, d):
        return self.mse(y, d)

# DUDnCNN Model
class DUDnCNN(NNRegressor):
    def __init__(self, D, C=64):
        super(DUDnCNN, self).__init__()
        self.D = D
        k = [0] + [i for i in range(D//2)] + [D//2]*(D//2+1)
        l = [0]*(D//2+1) + [i for i in range(D+1-(D//2+1))] + [D//2]
        holes = [2**(kl[0]-kl[1])-1 for kl in zip(k, l)]
        dilations = [i+1 for i in holes]
        
        self.conv = nn.ModuleList()
        self.conv.append(nn.Conv2d(3, C, 3, padding=dilations[0], dilation=dilations[0]))
        self.conv.extend([nn.Conv2d(C, C, 3, padding=dilations[i+1], dilation=dilations[i+1]) for i in range(D)])
        self.conv.append(nn.Conv2d(C, 3, 3, padding=dilations[-1], dilation=dilations[-1]))
        
        self.bn = nn.ModuleList()
        self.bn.extend([nn.BatchNorm2d(C) for _ in range(D)])

    def forward(self, x):
        D = self.D
        h = nn.functional.relu(self.conv[0](x))
        h_buff = []
        for i in range(D//2 - 1):
            h = nn.functional.relu(self.bn[i](self.conv[i+1](h)))
            h_buff.append(h)
        for i in range(D//2 - 1, D//2 + 1):
            h = nn.functional.relu(self.bn[i](self.conv[i+1](h)))
        for i in range(D//2 + 1, D):
            j = i - (D//2 + 1) + 1
            h = nn.functional.relu(self.bn[i](self.conv[i+1]((h + h_buff[-j]) / 1.41421356237)))  # Precomputed sqrt(2)
        y = self.conv[D+1](h) + x
        return y

# Optimized transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Simplified Test-Time Augmentation (TTA) function
def apply_tta(net, image):
    augmentations = [
        image,                          # Original
        torch.flip(image, [2]),         # Horizontal flip only (reduced for less blurring)
    ]
    
    denoised_outputs = []
    with torch.no_grad():
        for aug_img in augmentations:
            aug_img = aug_img.unsqueeze(0).to(device, non_blocking=True)
            with torch.amp.autocast('cuda'):
                denoised = net(aug_img)
            # Reverse the augmentation
            if aug_img is augmentations[1]:
                denoised = torch.flip(denoised, [3])
            denoised_outputs.append(denoised.squeeze(0))
    
    # Average the outputs
    return torch.mean(torch.stack(denoised_outputs), dim=0)

# Revised Post-processing function
def post_process(denoised_img):
    img = np.moveaxis(denoised_img, 0, -1)  # CHW to HWC
    img = (img * 255).astype(np.uint8)
    
    # Lighter bilateral filtering to avoid over-smoothing
    img = cv2.bilateralFilter(img, d=5, sigmaColor=25, sigmaSpace=25)
    
    # Adjusted sharpening for subtle detail enhancement
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])  # Stronger center weight
    img = cv2.filter2D(img, -1, kernel)
    
    return img

def test_model(checkpoint_path, test_dir, output_dir="/kaggle/working/denoised_images", batch_size=4):
    # Initialize model
    net = DUDnCNN(D=6, C=64).to(device)
    net.eval()
    
    # Load checkpoint with weights_only=True
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)
        net.load_state_dict(checkpoint['Net'])
    except Exception as e:
        print(f"Error loading checkpoint: {e}")
        return
    
    # Optimized DataLoader
    test_dataset = TestDenoisingDataset(test_dir=test_dir, transform=transform)
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
        prefetch_factor=2
    )
    
    os.makedirs(output_dir, exist_ok=True)
    
    total_time = 0
    num_images = 0
    
    denorm_factor = torch.tensor([0.5], device=device)
    denorm_bias = torch.tensor([0.5], device=device)
    
    for noisy_images, filenames in test_loader:
        start_time = time.time()
        noisy_images = noisy_images.to(device, non_blocking=True)
        
        # Apply simplified TTA and denoise
        denoised_images = torch.stack([apply_tta(net, img) for img in noisy_images])
        
        # Denormalize
        denoised_images = (denoised_images * denorm_factor) + denorm_bias
        denoised_images = torch.clamp(denoised_images, 0, 1)
        
        # Process original sizes and save
        original_sizes = [Image.open(os.path.join(test_dataset.test_dir, fname)).size for fname in filenames]
        denoised_batch = denoised_images.cpu().numpy()
        
        for i, (filename, orig_size) in enumerate(zip(filenames, original_sizes)):
            denoised_img = post_process(denoised_batch[i])
            output_path = os.path.join(output_dir, filename)
            
            img = Image.fromarray(denoised_img)
            img = img.resize(orig_size, Image.Resampling.LANCZOS)
            img.save(output_path, 'PNG', compress_level=0)
            print(f"Saved denoised image: {output_path}")
        
        end_time = time.time()
        total_time += (end_time - start_time)
        num_images += len(filenames)
        
        # Clean up memory
        del noisy_images, denoised_images, denoised_batch
        torch.cuda.empty_cache()
    
    avg_runtime = total_time / num_images if num_images > 0 else 0
    print(f"Average runtime per image: {avg_runtime:.4f} seconds")
    print("Denoising complete! Output directory:", output_dir)

if __name__ == '__main__':
    checkpoint_path = "/kaggle/input/checkpoint/checkpoint.pth.tar"
    test_dir = "/kaggle/input/test-data"
    test_model(checkpoint_path, test_dir)
# Out:
# Saved denoised image: /kaggle/working/denoised_images/0000089.png
# Saved denoised image: /kaggle/working/denoised_images/0000014.png
# Saved denoised image: /kaggle/working/denoised_images/0000026.png
# Saved denoised image: /kaggle/working/denoised_images/0968.png
# Saved denoised image: /kaggle/working/denoised_images/0947.png
# Saved denoised image: /kaggle/working/denoised_images/1000.png
# Saved denoised image: /kaggle/working/denoised_images/0950.png
# Saved denoised image: /kaggle/working/denoised_images/0971.png
# Saved denoised image: /kaggle/working/denoised_images/0940.png
# Saved denoised image: /kaggle/working/denoised_images/0000056.png
# Saved denoised image: /kaggle/working/denoised_images/0000019.png
# Saved denoised image: /kaggle/working/denoised_images/0000030.png
# Saved denoised image: /kaggle/working/denoised_images/0000021.png
# Saved denoised image: /kaggle/working/denoised_images/0000070.png
# Saved denoised image: /kaggle/working/denoised_images/0000099.png
# Saved denoised image: /kaggle/working/denoised_images/0905.png
# Saved denoised image: /kaggle/working/denoised_images/0974.png
# Saved denoised image: /kaggle/working/denoised_images/0985.png
# Saved denoised image: /kaggle/working/denoised_images/0000020.png
# Saved denoised image: /kaggle/working/denoised_images/0958.png
# Saved denoised image: /kaggle/working/denoised_images/0910.png
# Saved denoised image: /kaggle/working/denoised_images/0917.png
# Saved denoised image: /kaggle/working/denoised_images/0000087.png
# Saved denoised image: /kaggle/working/denoised_images/0914.png
# Saved denoised image: /kaggle/working/denoised_images/0000035.png
# Saved denoised image: /kaggle/working/denoised_images/0000005.png
# Saved denoised image: /kaggle/working/denoised_images/0972.png
# Saved denoised image: /kaggle/working/denoised_images/0967.png
# Saved denoised image: /kaggle/working/denoised_images/0948.png
# Saved denoised image: /kaggle/working/denoised_images/0920.png
# Saved denoised image: /kaggle/working/denoised_images/0000042.png
# Saved denoised image: /kaggle/working/denoised_images/0928.png
# Saved denoised image: /kaggle/working/denoised_images/0907.png
# Saved denoised image: /kaggle/working/denoised_images/0990.png
# Saved denoised image: /kaggle/working/denoised_images/0000068.png
# Saved denoised image: /kaggle/working/denoised_images/0933.png
# Saved denoised image: /kaggle/working/denoised_images/0000097.png
# Saved denoised image: /kaggle/working/denoised_images/0975.png
# Saved denoised image: /kaggle/working/denoised_images/0000033.png
# Saved denoised image: /kaggle/working/denoised_images/0945.png
# Saved denoised image: /kaggle/working/denoised_images/0000067.png
# Saved denoised image: /kaggle/working/denoised_images/0000027.png
# Saved denoised image: /kaggle/working/denoised_images/0000016.png
# Saved denoised image: /kaggle/working/denoised_images/0969.png
# Saved denoised image: /kaggle/working/denoised_images/0960.png
# Saved denoised image: /kaggle/working/denoised_images/0964.png
# Saved denoised image: /kaggle/working/denoised_images/0000065.png
# Saved denoised image: /kaggle/working/denoised_images/0000041.png
# Saved denoised image: /kaggle/working/denoised_images/0000047.png
# Saved denoised image: /kaggle/working/denoised_images/0941.png
# Saved denoised image: /kaggle/working/denoised_images/0000058.png
# Saved denoised image: /kaggle/working/denoised_images/0911.png
# Saved denoised image: /kaggle/working/denoised_images/0000031.png
# Saved denoised image: /kaggle/working/denoised_images/0994.png
# Saved denoised image: /kaggle/working/denoised_images/0000023.png
# Saved denoised image: /kaggle/working/denoised_images/0000046.png
# Saved denoised image: /kaggle/working/denoised_images/0000081.png
# Saved denoised image: /kaggle/working/denoised_images/0000091.png
# Saved denoised image: /kaggle/working/denoised_images/0978.png
# Saved denoised image: /kaggle/working/denoised_images/0000098.png
# Saved denoised image: /kaggle/working/denoised_images/0000010.png
# Saved denoised image: /kaggle/working/denoised_images/0000003.png
# Saved denoised image: /kaggle/working/denoised_images/0999.png
# Saved denoised image: /kaggle/working/denoised_images/0000017.png
# Saved denoised image: /kaggle/working/denoised_images/0000057.png
# Saved denoised image: /kaggle/working/denoised_images/0000001.png
# Saved denoised image: /kaggle/working/denoised_images/0000025.png
# Saved denoised image: /kaggle/working/denoised_images/0919.png
# Saved denoised image: /kaggle/working/denoised_images/0979.png
# Saved denoised image: /kaggle/working/denoised_images/0982.png
# Saved denoised image: /kaggle/working/denoised_images/0981.png
# Saved denoised image: /kaggle/working/denoised_images/0000088.png
# Saved denoised image: /kaggle/working/denoised_images/0983.png
# Saved denoised image: /kaggle/working/denoised_images/0000038.png
# Saved denoised image: /kaggle/working/denoised_images/0000093.png
# Saved denoised image: /kaggle/working/denoised_images/0000040.png
# Saved denoised image: /kaggle/working/denoised_images/0923.png
# Saved denoised image: /kaggle/working/denoised_images/0000069.png
# Saved denoised image: /kaggle/working/denoised_images/0956.png
# Saved denoised image: /kaggle/working/denoised_images/0987.png
# Saved denoised image: /kaggle/working/denoised_images/0000007.png
# Saved denoised image: /kaggle/working/denoised_images/0996.png
# Saved denoised image: /kaggle/working/denoised_images/0904.png
# Saved denoised image: /kaggle/working/denoised_images/0925.png
# Saved denoised image: /kaggle/working/denoised_images/0000037.png
# Saved denoised image: /kaggle/working/denoised_images/0000063.png
# Saved denoised image: /kaggle/working/denoised_images/0000083.png
# Saved denoised image: /kaggle/working/denoised_images/0913.png
# Saved denoised image: /kaggle/working/denoised_images/0939.png
# Saved denoised image: /kaggle/working/denoised_images/0908.png
# Saved denoised image: /kaggle/working/denoised_images/0926.png
# Saved denoised image: /kaggle/working/denoised_images/0965.png
# Saved denoised image: /kaggle/working/denoised_images/0000053.png
# Saved denoised image: /kaggle/working/denoised_images/0988.png
# Saved denoised image: /kaggle/working/denoised_images/0989.png
# Saved denoised image: /kaggle/working/denoised_images/0000059.png
# Saved denoised image: /kaggle/working/denoised_images/0000096.png
# Saved denoised image: /kaggle/working/denoised_images/0903.png
# Saved denoised image: /kaggle/working/denoised_images/0992.png
# Saved denoised image: /kaggle/working/denoised_images/0000054.png
# Saved denoised image: /kaggle/working/denoised_images/0936.png
# Saved denoised image: /kaggle/working/denoised_images/0995.png
# Saved denoised image: /kaggle/working/denoised_images/0980.png
# Saved denoised image: /kaggle/working/denoised_images/0961.png
# Saved denoised image: /kaggle/working/denoised_images/0902.png
# Saved denoised image: /kaggle/working/denoised_images/0901.png
# Saved denoised image: /kaggle/working/denoised_images/0000100.png
# Saved denoised image: /kaggle/working/denoised_images/0000008.png
# Saved denoised image: /kaggle/working/denoised_images/0966.png
# Saved denoised image: /kaggle/working/denoised_images/0986.png
# Saved denoised image: /kaggle/working/denoised_images/0929.png
# Saved denoised image: /kaggle/working/denoised_images/0921.png
# Saved denoised image: /kaggle/working/denoised_images/0000034.png
# Saved denoised image: /kaggle/working/denoised_images/0000029.png
# Saved denoised image: /kaggle/working/denoised_images/0000043.png
# Saved denoised image: /kaggle/working/denoised_images/0915.png
# Saved denoised image: /kaggle/working/denoised_images/0000060.png
# Saved denoised image: /kaggle/working/denoised_images/0973.png
# Saved denoised image: /kaggle/working/denoised_images/0984.png
# Saved denoised image: /kaggle/working/denoised_images/0000076.png
# Saved denoised image: /kaggle/working/denoised_images/0951.png
# Saved denoised image: /kaggle/working/denoised_images/0000012.png
# Saved denoised image: /kaggle/working/denoised_images/0000079.png
# Saved denoised image: /kaggle/working/denoised_images/0000086.png
# Saved denoised image: /kaggle/working/denoised_images/0000009.png
# Saved denoised image: /kaggle/working/denoised_images/0000082.png
# Saved denoised image: /kaggle/working/denoised_images/0998.png
# Saved denoised image: /kaggle/working/denoised_images/0944.png
# Saved denoised image: /kaggle/working/denoised_images/0997.png
# Saved denoised image: /kaggle/working/denoised_images/0000015.png
# Saved denoised image: /kaggle/working/denoised_images/0954.png
# Saved denoised image: /kaggle/working/denoised_images/0000039.png
# Saved denoised image: /kaggle/working/denoised_images/0000004.png
# Saved denoised image: /kaggle/working/denoised_images/0000084.png
# Saved denoised image: /kaggle/working/denoised_images/0000062.png
# Saved denoised image: /kaggle/working/denoised_images/0959.png
# Saved denoised image: /kaggle/working/denoised_images/0000095.png
# Saved denoised image: /kaggle/working/denoised_images/0000049.png
# Saved denoised image: /kaggle/working/denoised_images/0000018.png
# Saved denoised image: /kaggle/working/denoised_images/0000055.png
# Saved denoised image: /kaggle/working/denoised_images/0000028.png
# Saved denoised image: /kaggle/working/denoised_images/0000061.png
# Saved denoised image: /kaggle/working/denoised_images/0000050.png
# Saved denoised image: /kaggle/working/denoised_images/0000072.png
# Saved denoised image: /kaggle/working/denoised_images/0000048.png
# Saved denoised image: /kaggle/working/denoised_images/0000071.png
# Saved denoised image: /kaggle/working/denoised_images/0912.png
# Saved denoised image: /kaggle/working/denoised_images/0000078.png
# Saved denoised image: /kaggle/working/denoised_images/0993.png
# Saved denoised image: /kaggle/working/denoised_images/0937.png
# Saved denoised image: /kaggle/working/denoised_images/0000011.png
# Saved denoised image: /kaggle/working/denoised_images/0000044.png
# Saved denoised image: /kaggle/working/denoised_images/0000002.png
# Saved denoised image: /kaggle/working/denoised_images/0000036.png
# Saved denoised image: /kaggle/working/denoised_images/0000051.png
# Saved denoised image: /kaggle/working/denoised_images/0927.png
# Saved denoised image: /kaggle/working/denoised_images/0000074.png
# Saved denoised image: /kaggle/working/denoised_images/0000064.png
# Saved denoised image: /kaggle/working/denoised_images/0909.png
# Saved denoised image: /kaggle/working/denoised_images/0000045.png
# Saved denoised image: /kaggle/working/denoised_images/0000006.png
# Saved denoised image: /kaggle/working/denoised_images/0949.png
# Saved denoised image: /kaggle/working/denoised_images/0991.png
# Saved denoised image: /kaggle/working/denoised_images/0970.png
# Saved denoised image: /kaggle/working/denoised_images/0943.png
# Saved denoised image: /kaggle/working/denoised_images/0957.png
# Saved denoised image: /kaggle/working/denoised_images/0000052.png
# Saved denoised image: /kaggle/working/denoised_images/0922.png
# Saved denoised image: /kaggle/working/denoised_images/0955.png
# Saved denoised image: /kaggle/working/denoised_images/0953.png
# Saved denoised image: /kaggle/working/denoised_images/0000094.png
# Saved denoised image: /kaggle/working/denoised_images/0942.png
# Saved denoised image: /kaggle/working/denoised_images/0935.png
# Saved denoised image: /kaggle/working/denoised_images/0000032.png
# Saved denoised image: /kaggle/working/denoised_images/0000066.png
# Saved denoised image: /kaggle/working/denoised_images/0930.png
# Saved denoised image: /kaggle/working/denoised_images/0918.png
# Saved denoised image: /kaggle/working/denoised_images/0000090.png
# Saved denoised image: /kaggle/working/denoised_images/0000092.png
# Saved denoised image: /kaggle/working/denoised_images/0952.png
# Saved denoised image: /kaggle/working/denoised_images/0932.png
# Saved denoised image: /kaggle/working/denoised_images/0977.png
# Saved denoised image: /kaggle/working/denoised_images/0000013.png
# Saved denoised image: /kaggle/working/denoised_images/0906.png
# Saved denoised image: /kaggle/working/denoised_images/0000085.png
# Saved denoised image: /kaggle/working/denoised_images/0976.png
# Saved denoised image: /kaggle/working/denoised_images/0916.png
# Saved denoised image: /kaggle/working/denoised_images/0962.png
# Saved denoised image: /kaggle/working/denoised_images/0946.png
# Saved denoised image: /kaggle/working/denoised_images/0000024.png
# Saved denoised image: /kaggle/working/denoised_images/0000022.png
# Saved denoised image: /kaggle/working/denoised_images/0924.png
# Saved denoised image: /kaggle/working/denoised_images/0000075.png
# Saved denoised image: /kaggle/working/denoised_images/0963.png
# Saved denoised image: /kaggle/working/denoised_images/0000077.png
# Saved denoised image: /kaggle/working/denoised_images/0934.png
# Saved denoised image: /kaggle/working/denoised_images/0000080.png
# Saved denoised image: /kaggle/working/denoised_images/0938.png
# Saved denoised image: /kaggle/working/denoised_images/0000073.png
# Saved denoised image: /kaggle/working/denoised_images/0931.png
# Average runtime per image: 0.1621 seconds
# Denoising complete! Output directory: /kaggle/working/denoised_images
